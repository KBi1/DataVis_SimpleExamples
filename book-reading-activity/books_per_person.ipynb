# %%
# Importing the necessary libraries
import matplotlib.pyplot as plt
from google.colab import files
import pandas as pd

# %%
# Sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace'],
    'Books Read': [3, 1, 5, 2, 4, 2, 6]
}

# %%
# Create a DataFrame
df_books = pd.DataFrame(data)

# %%
# Display the dataset
print("Dataset:")
print(df_books)
# Out:
# Dataset:
#       Name  Books Read
# 0    Alice           3
# 1      Bob           1
# 2  Charlie           5
# 3    David           2
# 4      Eva           4
# 5    Frank           2
# 6    Grace           6

# %%
# Plotting a bar chart for books read
plt.bar(df_books['Name'], df_books['Books Read'], color='#9cc1b5') # You can use a variety of color names like 'red',etc., or you can use hex color codes

# Set the label for the x-axis
plt.xlabel('Name')

# Set the label for the y-axis
plt.ylabel('Number of Books Read')

# Set the title of the plot
plt.title('Books Read per Person')

# Save the plot
plt.savefig("books_read_chart_result.png")

# Display the plot
plt.show()

# Download the saved plot
files.download("books_read_chart_result.png")
